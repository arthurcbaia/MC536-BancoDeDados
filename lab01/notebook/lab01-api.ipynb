# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %% [markdown]
# # JSON

# %%
import requests
import pandas as pd
import json
from api_data import api_key

url = "https://restcountries-v1.p.rapidapi.com/all"

headers = {
    'x-rapidapi-host': "restcountries-v1.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers)
info = json.loads(response.text)
for c in info:
    if c['name'] == 'Brazil':
        for key, value in c.items():
            print(key,': ',value)
# Out:
# name :  Brazil
# topLevelDomain :  ['.br']
# alpha2Code :  BR
# alpha3Code :  BRA
# callingCodes :  ['55']
# capital :  Brasília
# altSpellings :  ['BR', 'Brasil', 'Federative Republic of Brazil', 'República Federativa do Brasil']
# region :  Americas
# subregion :  South America
# population :  204772000
# latlng :  [-10.0, -55.0]
# demonym :  Brazilian
# area :  8515767.0
# gini :  54.7
# timezones :  ['UTC-05:00', 'UTC-04:00', 'UTC-03:00', 'UTC-02:00']
# borders :  ['ARG', 'BOL', 'COL', 'GUF', 'GUY', 'PRY', 'PER', 'SUR', 'URY', 'VEN']
# nativeName :  Brasil
# numericCode :  076
# currencies :  ['BRL']
# languages :  ['pt']
# translations :  {'de': 'Brasilien', 'es': 'Brasil', 'fr': 'Brésil', 'ja': 'ブラジル', 'it': 'Brasile'}
# relevance :  2

# %% [markdown]
# # CSV

# %%
# !kaggle datasets download -d gpreda/covid-world-vaccination-progress
# Out:
# covid-world-vaccination-progress.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
df = pd.read_csv('/home/arthur/Documentos/BancoDeDadosMC536/MC536-BancoDeDados/lab01/notebook/country_vaccinations.csv')
df.loc[df['country']=='Brazil']
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 4856  Brazil      BRA  2021-01-16                 0.0                0.0
# 4857  Brazil      BRA  2021-01-17               112.0              112.0
# 4858  Brazil      BRA  2021-01-18              1109.0             1109.0
# 4859  Brazil      BRA  2021-01-19             11470.0            11470.0
# 4860  Brazil      BRA  2021-01-20             28543.0            28543.0
# ...      ...      ...         ...                 ...                ...
# 5064  Brazil      BRA  2021-08-12                 NaN                NaN
# 5065  Brazil      BRA  2021-08-13                 NaN                NaN
# 5066  Brazil      BRA  2021-08-14         163452602.0        116123404.0
# 5067  Brazil      BRA  2021-08-15         164638573.0        119793423.0
# 5068  Brazil      BRA  2021-08-16         168157560.0        121838235.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
