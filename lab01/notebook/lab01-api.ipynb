# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %% [markdown]
# # JSON

# %%
import requests
import pandas as pd
import json
from api_data import api_key

url = "https://restcountries-v1.p.rapidapi.com/all"

headers = {
    'x-rapidapi-host': "restcountries-v1.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers)
info = json.loads(response.text)
for i in info:
    print(i['name'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_276/2270672060.py in <module>
#       2 import pandas as pd
#       3 import json
# ----> 4 from api_data import api_key
#       5
#       6 url = "https://restcountries-v1.p.rapidapi.com/all"
#
# ModuleNotFoundError: No module named 'api_data'

# %% [markdown]
# # CSV

# %%
# !kaggle datasets download -d gpreda/covid-world-vaccination-progress
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/arthur/.kaggle/kaggle.json'
# covid-world-vaccination-progress.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
df = pd.read_csv('/home/arthur/Documentos/BancoDeDadosMC536/MC536-BancoDeDados/lab01/notebook/country_vaccinations.csv')
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 38639     Zimbabwe      ZWE  2021-08-14           3234909.0
# 38640     Zimbabwe      ZWE  2021-08-15           3289258.0
# 38641     Zimbabwe      ZWE  2021-08-16           3345985.0
# 38642     Zimbabwe      ZWE  2021-08-17           3450959.0
# 38643     Zimbabwe      ZWE  2021-08-18           3542340.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 38639          2036008.0                1198901.0                     NaN
# 38640          2064023.0                1225235.0                 54349.0
# 38641          2091259.0                1254726.0                 56727.0
# 38642          2145237.0                1305722.0                104974.0
# 38643          2193046.0                1349294.0                 91381.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 38639             54502.0                           21.76
# 38640             57530.0                           22.13
# 38641             57782.0                           22.51
# 38642             68200.0                           23.22
# 38643             75000.0                           23.83
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 38639                          13.70                                 8.07
# 38640                          13.89                                 8.24
# 38641                          14.07                                 8.44
# 38642                          14.43                                 8.79
# 38643                          14.76                                 9.08
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                35.0
# 2                                35.0
# 3                                35.0
# 4                                35.0
# ...                               ...
# 38639                          3667.0
# 38640                          3871.0
# 38641                          3888.0
# 38642                          4589.0
# 38643                          5046.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 38639  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 38640  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 38641  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 38642  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 38643  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 38639         Ministry of Health
# 38640         Ministry of Health
# 38641         Ministry of Health
# 38642         Ministry of Health
# 38643         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 38639  https://www.arcgis.com/home/webmap/viewer.html...
# 38640  https://www.arcgis.com/home/webmap/viewer.html...
# 38641  https://www.arcgis.com/home/webmap/viewer.html...
# 38642  https://www.arcgis.com/home/webmap/viewer.html...
# 38643  https://www.arcgis.com/home/webmap/viewer.html...
#
# [38644 rows x 15 columns]

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
